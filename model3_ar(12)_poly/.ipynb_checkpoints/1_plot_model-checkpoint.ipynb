# %% [markdown]
# #### 3

# %%
library(forecast)
library(ggplot2)
library(dplyr)
library(gridExtra)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘gridExtra’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
# library(doParallel)
library(doMC)
options(cores = 10)
registerDoMC()
# Out:
# Loading required package: foreach
# Loading required package: iterators
# Loading required package: parallel

# %% [markdown]
# ### ЕС

# %%
df_eu  <-  read.csv(file="../data_hts/hts_eu_a10.csv", header=TRUE, sep=",", row.names =1 )
df_eu  <-  df_eu/1000
var_freq  <- 4    
var_start_year  <- 2000   
gdp_agg <- df_eu_sums <-  rowSums(df_eu)
gdp_agg  <- ts(gdp_agg, frequency = var_freq, start = var_start_year)

# %%
var_h  <- 8
var_window  <-  48 - 1
var_topup  <-  1
var_iter   <- (length(gdp_agg)+var_topup)/var_freq-(var_window+1)/var_freq-2

# %%
# var_allornot  <- var_freq
var_allornot  <- 1
# var_shift  <-  var_topup
var_shift  <-  0

# %%
var_arpdq   <-  c(3,0,0)
var_sarpdq   <-  c(2,0,0)
var_drift   <-  FALSE
var_constant   <-  TRUE

# %%
l <- ac <- m_top  <- l_test  <-  list()

k  <- 0

for (i in 0:(var_iter*var_allornot - var_shift)){
    k  <-  k+1
    st_year  <-  var_start_year + i/var_allornot
    train_start  <- st_year 
    train_end  <- st_year + 1/var_freq*(var_window)
    test_start  <- st_year + 1/var_freq*(var_window+1) 
    test_end  <-  st_year + 1/var_freq*(var_window+var_h)
    
    print(c(train_start, train_end, test_start, test_end))
    
    if (i == 0){
        train <- window(gdp_agg, end=train_end)}
    else{
        if ((var_shift == 0) & (i == var_iter*var_allornot - var_shift)){
            train <- window(gdp_agg, start=train_start-var_topup/var_freq, end=train_end-var_topup/var_freq)
        }else{
            train <- window(gdp_agg, start=train_start, end=train_end)
    }}
    
    if ((var_shift == 0) & (i == var_iter*var_allornot - var_shift)){
        test <- window(gdp_agg, start=test_start-var_topup/var_freq)
    }else{    test <- window(gdp_agg, start=test_start, end=test_end)
        
    }
    
    t <- 1:length(train)
    regressors <- cbind(trend=t,quad=t^2)
        
    m_top[[k]]  <- Arima(train, order=var_arpdq, seasonal=var_sarpdq, xreg = regressors, include.drift = var_drift, include.mean = var_constant, method = "ML")
    
    t_f <- (length(train)+1):(length(train)+var_h)
    regressors_f <- cbind(trend=t_f,quad=t_f^2)
    
    l[[k]]  <-   forecast(m_top[[k]], h = var_h, xreg = regressors_f  )

    l_test[[i+1]]  <-   test
    
    ac[[i+1]]  <-  accuracy(l[[k]], test)

    }
# Out:
# [1] 2000.00 2011.75 2012.00 2013.75
# [1] 2001.00 2012.75 2013.00 2014.75
# [1] 2002.00 2013.75 2014.00 2015.75
# [1] 2003.00 2014.75 2015.00 2016.75
# [1] 2004.00 2015.75 2016.00 2017.75
# [1] 2005.00 2016.75 2017.00 2018.75

# %%
var_acc_metrics  <-  c(1,2,5)
df_acc_test  <- ac[[1]][2, var_acc_metrics]
for (i in ac[2:length(ac)]){
    x  <-  i[2, var_acc_metrics]
    df_acc_test   <-  cbind(df_acc_test, x)
}
df_acc_test  <- t(df_acc_test)
df_acc_test  <-  as.data.frame(df_acc_test)
row.names(df_acc_test)  <-  seq(1,length(ac))
df_acc_test
# Out:
#   ME        RMSE      MAPE
# 1  33.57291  43.09295 1.190258
# 2  41.31055  70.14746 1.800424
# 3 111.21447 135.53675 3.369613
# 4 102.56120 106.16113 3.067016
# 5 -70.09599  76.15499 2.083035
# 6  97.05184 102.44217 2.789127

# %%
colMeans(df_acc_test)
# Out:
#        ME      RMSE      MAPE
# 52.602496 88.922573  2.383245

# %%
plot_forecasts  <-  autoplot(window(gdp_agg, start=2010))+
    xlab("Время") + ylab('ВВП') +
    ggtitle("AR(3)SAR(2) с линейным трендом") +
    guides(colour=guide_legend(title=" ")) +
    theme(aspect.ratio = 0.75)

for (i in 1:length(l)){
    plot_forecasts  <-  plot_forecasts  +
    autolayer(l[[i]], series=paste("Итерация" , i, sep=" ") ,   PI=FALSE) 
    
}

plot_forecasts
# Out:
# plot without title

# %%
df_mean_acc <- readRDS("df_mean_acc.rds")

# %%
df_mean_acc[1,1]  <-  colMeans(df_acc_test)[[2]]
df_mean_acc
# Out:
#         Квартальные Сезонно сглаженные Месячные
# 1 level 88.92257    242.1291           9146.793
# 2             NA          NA                 NA
# 3             NA          NA                 NA
# 4             NA          NA                 NA
# 5             NA          NA                 NA

# %%
save_plots  <- list()

# %%
save_plots[[1]]  <-  plot_forecasts

# %%
df_acc  <-  df_acc_test

# %%
colnames(df_acc)  <-  colnames(ac[[1]])[var_acc_metrics] 
df_acc  <-  cbind(df_acc, seq(1, length(ac)))
colnames(df_acc)[length(var_acc_metrics)+1]  <-  'Iteration'

# %%
df_acc$Iteration  <-  df_acc$Iteration*var_freq-(var_freq-1)
df_acc$Iteration[length(df_acc$Iteration)]  <-   df_acc$Iteration[length(df_acc$Iteration)] - var_topup

# %%
df_acc
# Out:
#   ME        RMSE      MAPE     Iteration
# 1  33.57291  43.09295 1.190258  1
# 2  41.31055  70.14746 1.800424  5
# 3 111.21447 135.53675 3.369613  9
# 4 102.56120 106.16113 3.067016 13
# 5 -70.09599  76.15499 2.083035 17
# 6  97.05184 102.44217 2.789127 20

# %%
# Basic line plot with points

plots_test_all  <-  list()

var_col_test  <-  'red'
# var_col_train  <-  'red'

for (i in 1:3) {
    
    k = i + 0
    
    if  (i==1) {
        
        plots_test_all[[k]]  <- ggplot(data=df_acc, aes(x=Iteration, y=ME)) +
#             geom_line(aes(x=Iteration, y=ME_test), colour = var_col_train ) + 
            geom_line(colour=var_col_test) + labs(title = " ")  +
            theme(aspect.ratio = 1)+
            labs(y = "ME", x = 'Шаг')
        } else if (i==2) { 
            plots_test_all[[k]]  <- ggplot(data=df_acc, aes(x=Iteration, y=RMSE)) +
#             geom_line(aes(x=Iteration, y=RMSE_test), colour = var_col_train ) + 
            geom_line(colour=var_col_test)+
            theme(aspect.ratio = 1)+
            labs(y = "RMSE", x = 'Шаг')+ labs(title = "Квартальные") +
            theme(plot.title = element_text(hjust = 0.5))       
        } else if (i==3)  {
            plots_test_all[[k]]  <- ggplot(data=df_acc, aes(x=Iteration, y=MAPE)) +
#             geom_line(aes(x=Iteration, y=MAPE_test), colour = var_col_train ) + 
            geom_line(colour=var_col_test)+ labs(title = " ") +
            theme(aspect.ratio = 1)+
            labs(y = "MAPE", x = 'Шаг')   
    }        
    }

grid.arrange(grobs = plots_test_all, ncol = 3)
# Out:
# plot without title

# %%
var_allornot  <- var_freq
# var_allornot  <- 1
var_shift  <-  var_topup
# var_shift  <-  0

# %% [markdown]
# ### США

# %%
df_eu  <-  read.csv(file="../data_hts/hts_us_ind_filled.csv", header=TRUE, sep=",", row.names =1 )
df_eu  <-  df_eu/1000
var_freq  <- 4    
var_start_year  <- 2005   
gdp_agg <- df_eu_sums <-  rowSums(df_eu)
gdp_agg  <- ts(gdp_agg, frequency = var_freq, start = var_start_year)

# %%
var_h  <- 8
var_window  <-  28 - 1
var_topup  <-  2
var_iter   <- (length(gdp_agg)+var_topup)/var_freq-(var_window+1)/var_freq-2

# %%
# var_allornot  <- var_freq
var_allornot  <- 1
# var_shift  <-  var_topup
var_shift  <-  0

var_arpdq   <-  c(4,0,0)
var_sarpdq   <-  c(0,0,0)
var_drift   <-  FALSE
var_constant   <-  TRUE

# %%
l <- ac <- m_top  <- l_test  <-  list()

k  <- 0

for (i in 0:(var_iter*var_allornot - var_shift)){
    k  <-  k+1
    st_year  <-  var_start_year + i/var_allornot
    train_start  <- st_year 
    train_end  <- st_year + 1/var_freq*(var_window)
    test_start  <- st_year + 1/var_freq*(var_window+1) 
    test_end  <-  st_year + 1/var_freq*(var_window+var_h)
    
    print(c(train_start, train_end, test_start, test_end))
    
    if (i == 0){
        train <- window(gdp_agg, end=train_end)}
    else{
        if ((var_shift == 0) & (i == var_iter*var_allornot - var_shift)){
            train <- window(gdp_agg, start=train_start-var_topup/var_freq, end=train_end-var_topup/var_freq)
        }else{
            train <- window(gdp_agg, start=train_start, end=train_end)
    }}
    
    if ((var_shift == 0) & (i == var_iter*var_allornot - var_shift)){
        test <- window(gdp_agg, start=test_start-var_topup/var_freq)
    }else{    test <- window(gdp_agg, start=test_start, end=test_end)
        
    }
    
    t <- 1:length(train)
    regressors <- cbind(trend=t,quad=t^2)
        
    m_top[[k]]  <- Arima(train, order=var_arpdq, seasonal=var_sarpdq, xreg = regressors, include.drift = var_drift, include.mean = var_constant, method = "ML")
    
    t_f <- (length(train)+1):(length(train)+var_h)
    regressors_f <- cbind(trend=t_f,quad=t_f^2)
    
    l[[k]]  <-   forecast(m_top[[k]], h = var_h, xreg = regressors_f  )

    l_test[[i+1]]  <-   test
    
    ac[[i+1]]  <-  accuracy(l[[k]], test)
    
    }
# Out:
# [1] 2005.00 2011.75 2012.00 2013.75
# [1] 2006.00 2012.75 2013.00 2014.75
# [1] 2007.00 2013.75 2014.00 2015.75
# [1] 2008.00 2014.75 2015.00 2016.75
# [1] 2009.00 2015.75 2016.00 2017.75
# [1] 2010.00 2016.75 2017.00 2018.75

# %%
m_top
# Out:
# [[1]]
# Series: train
# Regression with ARIMA(4,0,0) errors
#
# Coefficients:
#          ar1      ar2      ar3     ar4   intercept    trend     quad
#       1.0587  -0.0327  -0.1501  -0.132  15011.7208  32.5187  -0.3392
# s.e.  0.1966   0.2976   0.2957   0.197    229.9636  36.1038   1.2000
#
# sigma^2 estimated as 12488:  log likelihood=-168.81
# AIC=353.63   AICc=361.2   BIC=364.28
#
# [[2]]
# Series: train
# Regression with ARIMA(4,0,0) errors
#
# Coefficients:
#          ar1      ar2      ar3      ar4   intercept     trend    quad
#       0.9753  -0.0344  -0.1933  -0.1431  15583.2247  -42.9556  2.0142
# s.e.  0.1852   0.2617   0.2590   0.1874    160.3742   25.5655  0.8410
#
# sigma^2 estimated as 9871:  log likelihood=-165.45
# AIC=346.9   AICc=354.48   BIC=357.56
#
# [[3]]
# Series: train
# Regression with ARIMA(4,0,0) errors
#
# Coefficients:
#          ar1      ar2      ar3      ar4   intercept     trend    quad
#       0.8404  -0.0350  -0.1813  -0.2106  15669.3604  -66.9368  3.4222
# s.e.  0.1807   0.2406   0.2411   0.1888    107.9969   17.3620  0.5813
#
# sigma^2 estimated as 8777:  log likelihood=-163.77
# AIC=343.54   AICc=351.12   BIC=354.2
#
# [[4]]
# Series: train
# Regression with ARIMA(4,0,0) errors
#
# Coefficients:
#          ar1      ar2      ar3      ar4   intercept     trend    quad
#       0.8696  -0.2013  -0.1478  -0.2145  15306.0072  -11.1416  2.3154
# s.e.  0.1921   0.2569   0.2874   0.2372    112.6953   17.3374  0.5648
#
# sigma^2 estimated as 9613:  log likelihood=-165.15
# AIC=346.3   AICc=353.88   BIC=356.96
#
# [[5]]
# Series: train
# Regression with ARIMA(4,0,0) errors
#
# Coefficients:
#          ar1      ar2      ar3      ar4   intercept    trend    quad
#       0.4693  -0.0228  -0.0431  -0.2522  15049.9540  46.4720  1.0437
# s.e.  0.1808   0.2057   0.2061   0.1909     49.9619   7.9065  0.2640
#
# sigma^2 estimated as 4590:  log likelihood=-154.06
# AIC=324.13   AICc=331.71   BIC=334.79
#
# [[6]]
# Series: train
# Regression with ARIMA(4,0,0) errors
#
# Coefficients:
#          ar1     ar2      ar3      ar4  intercept    trend    quad
#       0.4373  0.0174  -0.0914  -0.2554  15159.492  49.3381  1.0690
# s.e.  0.1902  0.2076   0.2128   0.1929     53.905   8.7354  0.2936
#
# sigma^2 estimated as 4526:  log likelihood=-153.89
# AIC=323.78   AICc=331.36   BIC=334.44

# %%
var_acc_metrics  <-  c(1,2,5)
df_acc_test  <- ac[[1]][2, var_acc_metrics]
for (i in ac[2:length(ac)]){
    x  <-  i[2, var_acc_metrics]
    df_acc_test   <-  cbind(df_acc_test, x)
}
df_acc_test  <- t(df_acc_test)
df_acc_test  <-  as.data.frame(df_acc_test)
row.names(df_acc_test)  <-  seq(1,length(ac))
df_acc_test
# Out:
#   ME        RMSE     MAPE
# 1  296.2562 363.1844 1.8289090
# 2  120.9038 131.4827 0.7350980
# 3 -310.7818 329.5962 1.8380225
# 4 -199.2063 250.7968 1.1505100
# 5 -147.3310 171.8917 0.8363753
# 6 -198.1492 205.8228 1.1170486

# %%
colMeans(df_acc_test)
# Out:
#         ME       RMSE       MAPE
# -73.051392 242.129119   1.250994

# %%
plot_forecasts  <-  autoplot(window(gdp_agg, start=2010))+
    xlab("Время") + ylab('ВВП') +
    ggtitle("AR(4)") +
    guides(colour=guide_legend(title=" ")) +
    theme(aspect.ratio = 0.75)

for (i in 1:length(l)){
    plot_forecasts  <-  plot_forecasts  +
    autolayer(l[[i]], series=paste("Итерация" , i, sep=" ") ,   PI=FALSE) 
    
}

plot_forecasts
# Out:
# plot without title

# %%
df_mean_acc[1,2]  <- colMeans(df_acc_test)[[2]]
df_mean_acc
# Out:
#         Квартальные Сезонно сглаженные Месячные
# 1 level 88.92257    242.1291           9146.793
# 2             NA          NA                 NA
# 3             NA          NA                 NA
# 4             NA          NA                 NA
# 5             NA          NA                 NA

# %%
save_plots[[3]]  <-  plot_forecasts

# %%
var_allornot  <- var_freq
# var_allornot  <- 1
var_shift  <-  var_topup
# var_shift  <-  0

# %% [markdown]
# ### РФ

# %%
df_eu  <-  read.csv(file="../data_hts/hts_rus_summed.csv", header=TRUE, sep=",", row.names =1 )
# df_eu  <-  df_eu/1000
var_freq  <- 12    
var_start_year  <- 2006   
gdp_agg <- df_eu_sums <-  rowSums(df_eu)
gdp_agg  <- ts(gdp_agg, frequency = var_freq, start = var_start_year)

# %%
var_h  <- 24
var_window  <-  84 - 1
var_topup  <-  -1
var_iter   <- (length(gdp_agg)+var_topup)/var_freq-(var_window+1)/var_freq-2

# %% [markdown]
# ### Top Level: AR(3)

# %%
# var_allornot  <- var_freq
var_allornot  <- 1
# var_shift  <-  var_topup
var_shift  <-  0

var_arpdq   <-  c(11,0,0)
var_sarpdq   <-  c(2,0,0)
var_drift   <-  FALSE
var_constant   <-  TRUE

# %%
require(svMisc)
# Out:
# Loading required package: svMisc
#
# Attaching package: ‘svMisc’
#
# The following object is masked from ‘package:utils’:
#
#     ?

# %%
l <- ac <- m_top  <- l_test  <-  list()

k  <- 0
err_list  <- c()
for (i in 0:(var_iter*var_allornot - var_shift)){
    k  <-  k+1
    st_year  <-  var_start_year + i/var_allornot
    train_start  <- st_year 
    train_end  <- st_year + 1/var_freq*(var_window)
    test_start  <- st_year + 1/var_freq*(var_window+1) 
    test_end  <-  st_year + 1/var_freq*(var_window+var_h)
    
#     print(c(train_start, train_end, test_start, test_end))
    
    if (i == 0){
        train <- window(gdp_agg, end=train_end)}
    else{
#         if ((var_shift == 0) & (i == var_iter*var_allornot - var_shift)){
#             train <- window(gdp_agg, start=train_start-var_topup/var_freq, end=train_end-var_topup/var_freq)
#         }else{
            train <- window(gdp_agg, start=train_start, end=train_end)
#     }
}
    
#     if ((var_shift == 0) & (i == var_iter*var_allornot - var_shift)){
#         test <- window(gdp_agg, start=test_start-var_topup/var_freq)
#     }else{    
        test <- window(gdp_agg, start=test_start, end=test_end)
        
#     }
    
    t <- 1:length(train)
    regressors <- cbind(trend=t,quad=t^2)
        
    
    model  <-  tryCatch( list(Arima(train, order=c(11,0,0), seasonal=c(2,0,0), xreg = regressors, include.drift = FALSE, include.constant = TRUE, method = "ML") , 0), 
            error = function(e) 
               {tryCatch( list( Arima(train, order=c(11,0,0), seasonal=c(2,0,0), xreg = regressors, include.drift = FALSE, include.constant = TRUE, method = "CSS"), i+1), 
                         error = function(e)              
                            list( Arima(train, order=c(11,0,0), seasonal=c(2,0,0), xreg = regressors, include.drift = FALSE, include.constant = TRUE, method = "CSS", optim.method = "SANN"), i+1))
                         }
    )

    
    m_top[[k]]  <- model[[1]]
    
    t_f <- (length(train)+1):(length(train)+var_h)
    regressors_f <- cbind(trend=t_f,quad=t_f^2)
    
    l[[k]]  <-   forecast(m_top[[k]], h = var_h, xreg = regressors_f  )

    if (model[[2]]!=0){
        err_list <-  c(err_list,model[[2]])
    }              
    
                
                
    l_test[[i+1]]  <-   test
    
    ac[[i+1]]  <-  accuracy(l[[k]], test)
                
    progress(i, progress.bar = TRUE)
    
                
    }
# Out:
#           0%---------25%---------50%---------75%--------100%
# Progress: ||

# %%
var_acc_metrics  <-  c(1,2,5)
df_acc_test  <- ac[[1]][2, var_acc_metrics]
for (i in ac[2:length(ac)]){
    x  <-  i[2, var_acc_metrics]
    df_acc_test   <-  cbind(df_acc_test, x)
}
df_acc_test  <- t(df_acc_test)
df_acc_test  <-  as.data.frame(df_acc_test)
row.names(df_acc_test)  <-  seq(1,length(ac))
df_acc_test
# Out:
#   ME         RMSE      MAPE
# 1  -1357.642  5556.373 143.40085
# 2  -7876.559  9549.523 219.31154
# 3   7055.057 10310.360 191.13163
# 4 -10044.473 12493.047 184.30615
# 5  -4160.280  8430.594  62.50178

# %%
colMeans(df_acc_test)
# Out:
#         ME       RMSE       MAPE
# -3276.7795  9267.9795   160.1304

# %%
err_list
# Out:
# [1] 3

# %%
plot_forecasts  <-  autoplot(window(gdp_agg, start=2010))+
    xlab("Время") + ylab('ЕП') +
    ggtitle("AR(11)SAR(2) с линейным трендом") +
    guides(colour=guide_legend(title=" ")) +
    theme(aspect.ratio = 0.75)

for (i in 1:length(l)){
    plot_forecasts  <-  plot_forecasts  +
    autolayer(l[[i]], series=paste("Итерация" , i, sep=" ") ,   PI=FALSE) 
    
}

plot_forecasts
# Out:
# plot without title

# %%
df_mean_acc[1,3]  <- colMeans(df_acc_test)[[2]]
df_mean_acc
# Out:
#         Квартальные Сезонно сглаженные Месячные
# 1 level 88.92257    242.1291           9267.979
# 2             NA          NA                 NA
# 3             NA          NA                 NA
# 4             NA          NA                 NA
# 5             NA          NA                 NA

# %%
save_plots[[5]]  <-  plot_forecasts

# %%
var_allornot  <- var_freq
# var_allornot  <- 1
var_shift  <-  var_topup
# var_shift  <-  0

# %%
df_mean_acc
# Out:
#         Квартальные Сезонно сглаженные Месячные
# 1 level 88.92257    242.1291           9267.979
# 2             NA          NA                 NA
# 3             NA          NA                 NA
# 4             NA          NA                 NA
# 5             NA          NA                 NA

# %%
saveRDS(df_mean_acc, "df_mean_acc.rds")
