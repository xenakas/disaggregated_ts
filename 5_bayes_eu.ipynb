# %%
library(forecast)
library(ggplot2)
library(dplyr)
library(data.table)

# %%
df_eu  <-  read.csv(file="hts_eu_a10.csv", header=TRUE, sep=",", row.names =1 )
df_eu  <-  as.data.table(df_eu)

# %%
df_eu  %>% head()
# Out:
#   BEA   BEB     BEF    BEG     BEJ    BEK  BEL    BEM    BEO     BER    ⋯
# 1 698.5 12887.5 2825.0 10591.5 2161.0 3509 5215.0 5877.5 11166.5 1211.0 ⋯
# 2 749.5 13162.0 3037.5 10809.5 2160.5 3558 5335.0 6166.0 11481.0 1260.0 ⋯
# 3 786.5 12941.0 2840.5 10664.5 2141.0 3569 5452.5 6301.0 11073.5 1257.5 ⋯
# 4 781.5 13301.0 3108.5 11425.5 2330.5 3535 5528.0 6625.5 11661.5 1311.5 ⋯
# 5 771.5 13219.5 2861.0 11164.5 2342.5 3452 5541.0 6534.5 11485.5 1246.5 ⋯
# 6 745.5 13211.0 3149.0 11561.5 2416.5 3414 5604.5 6665.5 12023.5 1297.0 ⋯
#   UKA     UKB      UKF      UKG      UKJ      UKK      UKL      UKM
# 1 3399.10 76488.40 22862.20 73151.90 23719.95 20741.50 57761.00 37932.55
# 2 3548.80 75447.70 23319.40 73312.00 24628.50 20607.85 57974.95 39850.10
# 3 3485.20 75416.75 23405.15 74807.70 25083.70 20351.05 58053.75 41213.95
# 4 3469.00 79694.75 24750.20 76852.75 25989.25 19280.20 59448.60 42271.75
# 5 3306.20 73919.55 22958.40 73992.25 24918.60 20554.10 57599.55 40398.35
# ...
