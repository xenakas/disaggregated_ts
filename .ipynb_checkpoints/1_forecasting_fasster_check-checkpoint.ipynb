# %% [markdown]
# #### [fasster](https://github.com/tidyverts/fasster)
#
# https://mitchelloharawild.com/melburn17/#74
#
# Special DLM components can be specified using special functions defined below:
#
# - `seas(s)`: Creates seasonal factors with seasonality s
#
# - `trig(s)`: Creates seasonal fourier terms with seasonality s
#
# - `poly(n)`: Creates a polynomial of order n (poly(1) creates a level, poly(2) creates a trend)
#
# - `ARMA(ar, ma)`: Creates ARMA terms with coefficient vectors ar and ma
#
# - `custom(dlm)`: Creates a custom dlm structure, using dlm

# %%
library(fasster)
library(dplyr)

# %%
gdp_agg <- read.csv(file="data/eu_gdp_eu28.csv", header=TRUE, sep=",")

# %%
gdp_agg  <- ts(gdp_agg$values, frequency = 4, start = 1995) 
plot(gdp_agg)
# Out:
# plot without title

# %%
time_count  <- seq(1, length(gdp_agg), by=1)

# %%
gdp_agg  <-  gdp_agg %>% 
  as_tsibble %>% mutate(d_value = value - lag(value)) %>% mutate(time_count)   %>%  mutate(time_count^2)  #%>% filter(index >= "2010-01-01")

# %%
train <- gdp_agg  %>% filter(  index <= lubridate::ymd("2016-10-01"))

# %%
test <- gdp_agg  %>% filter(  index > lubridate::ymd("2016-10-01"))

# %% [markdown]
# The model parameters are estimated using the following heuristic:
#
# - Filter the data using the specified model with non-zero state variances
#
# - Obtain smoothed states $(θ^{(s)}t=θ_t|D_T)$ to approximate correct behaviour
#
# - The initial state parameters taken from the first smoothed state: $m_0=E(θ^{(s)}_0), C_0=Var(θ^{(s)}_0)$
#
# - Obtain state noise variances from the smoothed variance of $w_t: W=Var(w^{(s)}_t)=Var(θ^{(s)}_t−Gθ^{(s)}_{t−1}) $
#
# - Obtain measurement noise variance from smoothed variance of $v_t: V=Var(v^{(s)}_t)=Var(y_t−F_tθ^{(s)}_t)$
#
# - Repair restricted state variances for seasonal factors and ARMA terms

# %%
fit  <-  train %>% as_tsibble() %>%
  model(fasster = FASSTER(value ~ poly(1) + trig(4) + 1))

fit %>% summary
# Out:
#            Length Class  Mode
# dlm         11    dlm    list
# dlm_future  11    dlm    list
# est          4    tbl_ts list
# states     440    -none- numeric

# %%
fit_in_diff  <- train %>%
  model(fasster = FASSTER(d_value ~ poly(1) + trig(4)))

# %%
fit %>% components() %>% tail()
# Out:
#   .model  index   value   (Intercept) poly(1) trig(4)
# 1 fasster 2015 Q3 3322218 833059.5    2427391 -16894.173
# 2 fasster 2015 Q4 3448333 833059.5    2467757  74708.744
# 3 fasster 2016 Q1 3265629 833059.5    2505120 -59472.479
# 4 fasster 2016 Q2 3368178 833059.5    2498409   1657.908
# 5 fasster 2016 Q3 3312360 833059.5    2516396 -16894.173
# 6 fasster 2016 Q4 3431287 833059.5    2506030  74708.744

# %%
gdp_fasster_in_diff  <- fit_in_diff %>% 
  forecast(h=24)
gdp_fasster  <- fit %>% 
  forecast(h=24)

autoplot(gdp_fasster, train)
# Out:
# plot without title

# %%
autoplot(gdp_fasster_in_diff, train)
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_path).”
# plot without title

# %%
fit_time  <-  train %>%
  model(fasster = FASSTER(value ~ poly(1) + trig(4) + time_count)) #+ time_count^2))
fit_time %>% summary
# Out:
#            Length Class  Mode
# dlm         11    dlm    list
# dlm_future  11    dlm    list
# est          4    tbl_ts list
# states     440    -none- numeric

# %%
fit_time %>% components() %>% tail()
# Out:
#   .model  index   value   poly(1) time_count trig(4)
# 1 fasster 2015 Q3 3322218 1645379 19911.68   -17308.237
# 2 fasster 2015 Q4 3448333 1666257 19911.68    73466.547
# 3 fasster 2016 Q1 3265629 1684392 19911.68   -58230.283
# 4 fasster 2016 Q2 3368178 1657702 19911.68     2071.973
# 5 fasster 2016 Q3 3312360 1655689 19911.68   -17308.237
# 6 fasster 2016 Q4 3431287 1626326 19911.68    73466.547

# %%
test_2  <-  test

# %%
gdp_fasster_time  <- fit_time %>% 
  forecast(new_data=test)

# %%
autoplot(gdp_fasster_time, train)
# Out:
# plot without title

# %%
fit_time_int  <-  train %>%
  model(fasster = FASSTER(value ~ poly(1) + trig(4) + time_count + 1)) #+ time_count^2))
gdp_fasster_time_int  <- fit_time_int %>% 
  forecast(new_data=test)

# %%
autoplot(gdp_fasster_time_int, train)
# Out:
# plot without title

# %%
fit_time_int %>% components() %>% tail()
# Out:
#   .model  index   value   (Intercept) poly(1)  time_count trig(4)
# 1 fasster 2015 Q3 3322218 809862.7    835516.2 19911.67   -17308.237
# 2 fasster 2015 Q4 3448333 809862.7    856394.0 19911.67    73466.550
# 3 fasster 2016 Q1 3265629 809862.7    874529.2 19911.67   -58230.285
# 4 fasster 2016 Q2 3368178 809862.7    847839.3 19911.67     2071.973
# 5 fasster 2016 Q3 3312360 809862.7    845826.0 19911.67   -17308.237
# 6 fasster 2016 Q4 3431287 809862.7    816463.0 19911.67    73466.550

# %%
fit_time_2  <-  train %>%
  model(fasster = FASSTER(value ~ poly(2) + trig(4) + time_count)) #+ time_count^2))
gdp_fasster_time_2  <- fit_time_2 %>% 
  forecast(new_data=test)

# %%
autoplot(gdp_fasster_time_2, train)
# Out:
# plot without title

# %%
fit_time_3  <-  train %>%
  model(fasster = FASSTER(value ~ poly(2) + trig(4) + time_count + time_count^2))
gdp_fasster_time_3  <- fit_time_3 %>% 
  forecast(new_data=test)

# %%
autoplot(gdp_fasster_time_3, train)
# Out:
# plot without title

# %%
accuracy(gdp_fasster_time, test)
# Out:
#   .model  .type ME       RMSE     MAE      MPE       MAPE      MASE ACF1
# 1 fasster Test  26835.21 32190.18 28195.94 0.7636227 0.8045463 NaN  0.1710553

# %%
library(forecast)
library(ggplot2)
# Out:
# Attaching package: ‘forecast’
#
# The following objects are masked from ‘package:fablelite’:
#
#     accuracy, forecast, geom_forecast, GeomForecast, StatForecast

# %%
auto.arima(ts(train$value, frequency = 4, start = 1995) )
# Out:
# Series: ts(train$value, frequency = 4, start = 1995)
# ARIMA(2,0,1)(0,1,1)[4] with drift
#
# Coefficients:
#          ar1      ar2      ma1     sma1      drift
#       1.6114  -0.6827  -0.3994  -0.6894  19481.575
# s.e.  0.1633   0.1518   0.2059   0.1050   2144.301
#
# sigma^2 estimated as 817681831:  log likelihood=-980.68
# AIC=1973.35   AICc=1974.44   BIC=1987.94

# %%
gdp_arima  <- forecast(auto.arima(ts(train$value, frequency = 4, start = 1995) ), h=7)
accuracy(gdp_arima, test$value)
# Out:
#              ME         RMSE     MAE      MPE        MAPE      MASE
# Training set   496.5713 27093.45 18745.11 0.04021781 0.7075616 0.2364942
# Test set     53108.4852 54480.16 53108.49 1.52742685 1.5274268 0.6700335
#              ACF1
# Training set -0.006078177
# Test set               NA

# %%
gdp_fasster_time
# Out:
#   .model  index   value   .distribution       d_value   time_count time_count^2
# 1 fasster 2017 Q1 3329799 N(3329799, 2.0e+09) -106250.8 89         7921
# 2 fasster 2017 Q2 3410013 N(3410013, 2.4e+09)  105133.7 90         8100
# 3 fasster 2017 Q3 3410544 N(3410544, 2.8e+09)   -6337.7 91         8281
# 4 fasster 2017 Q4 3521231 N(3521231, 3.2e+09)  139787.3 92         8464
# 5 fasster 2018 Q1 3409446 N(3409446, 3.5e+09) -129236.9 93         8649
# 6 fasster 2018 Q2 3489659 N(3489659, 3.9e+09)  103658.3 94         8836
# 7 fasster 2018 Q3 3490191 N(3490191, 4.3e+09)   -4394.0 95         9025

# %%
gdp_arima$mean
# Out:
# Time Series:
# Start = 89
# End = 95
# Frequency = 1
# [1] 3386354 3450346 3441931 3481648 3489370 3518360 3533212

# %%
ts(gdp_arima$mean, frequency = 4, start = 2017)
# Out:
#         Qtr1    Qtr2    Qtr3    Qtr4
# 2017 3290122 3388450 3382414 3502656
# 2018 3369567 3473300 3470461

# %%
autoplot(window(ts(gdp_agg$value, frequency = 4, start = 1995), start=2012 )) +
    autolayer(window(ts(gdp_fasster_time$value, frequency = 4, start = 2017), end =c(2018,3))  , series="FASSTER") +
    autolayer(ts(gdp_arima$mean, frequency = 4, start = 2017), series="Auto ARIMA", PI=FALSE) +
    xlab("Year") + ylab("Mln. Euro") +
    ggtitle("Модель 0, 00") +
    guides(colour=guide_legend(title="Forecast")) +
    theme(aspect.ratio = 0.75)
# Out:
# Warning message:
# “Ignoring unknown parameters: PI”
# plot without title
