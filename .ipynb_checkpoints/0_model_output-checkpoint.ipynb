# %%
library(gridExtra)

# %%
modelz  <-  c('model1_ar(2)_lin',
'model2_ar(12)_lin',
'model3_ar(12)_poly',
'model4_ari',
'model5_arma',
'model6_arima',
'model7_auto.arima',
'model8_ets',
'model9_auto.ets',
'model_10_tbats')

# %%
a  <- b <-  list()
for (i in 1:length(modelz)){
    a[[i]]  <- readRDS(paste(modelz[i],'df_mean_acc.rds', sep='/'))
    b[[i]]  <- readRDS(paste(modelz[i],'plots_test_not_all.rds', sep='/'))
}

paramz = readRDS("df_params.rds")

# %%
r_names  <- c('AR с малым числом лагов',  'AR с линейным трендом', 'AR с квадратичным трендом', 'Интегрированная AR', 'ARMA с линейным трендом', 'ARIMA', 'ARIMA с автом. подбором', 'ETS', 'ETS с автом. подбором', 'TBATS' )

# %%
params_score  <-  a[[1]][1,]
for (i in 2:length(a)){
    params_score <-  rbind(params_score, a[[i]][1,])
}

# %%
colnames(params_score)  <-  c('Квартальные', 'Сезонно.сглаженные', 'Месячные')
rownames(params_score)  <- r_names

# %%
params_score = params_score[order(params_score$Квартальные),]
params_score['order_eu'] = seq(1, dim(params_score)[1])
params_score = params_score[order(params_score$Сезонно.сглаженные),]
params_score['order_us'] = seq(1, dim(params_score)[1])
params_score = params_score[order(params_score$Месячные),]
params_score['order_rus'] = seq(1, dim(params_score)[1])
params_score = params_score[r_names,]

# %%
params_score['names_eu']  <- rownames(params_score)[params_score[,4]]
params_score['names_us']  <- rownames(params_score)[params_score[,5]]
params_score['names_rus']  <- rownames(params_score)[params_score[,6]]

# %%
i = 1
paramz[i,]
a[[i]]
grid.arrange(grobs = b[[i]] , ncol = 3)
# Out:
#                  Квартальные
# AR_1 (лин.тренд) order=c(2,0,0), \n    seasonal=c(1,0,0), include.drift = TRUE, include.constant = TRUE
#                  Сезонно сглаженные
# AR_1 (лин.тренд) order=c(2,0,0), \n     include.drift = TRUE, include.constant = TRUE
#                  Месячные
# AR_1 (лин.тренд) order=c(2,0,0),\n    seasonal=c(1,0,0), include.drift = TRUE, include.constant = TRUE)
#                      Квартальные Сезонно сглаженные Месячные
# 1 level              64.30372    299.5702           15884.63
# 3 level              64.24503    298.8763           15346.86
# 2 level (state)      64.23140    298.8923           15342.24
# 2 level (type)       64.10458    299.4158           15511.31
# 2 level (clusetered) 64.25570    297.5359           15338.88
# plot without title

# %%
i = 2
paramz[i,]
a[[i]]
grid.arrange(grobs = b[[i]] , ncol = 3)
# Out:
#                  Квартальные
# AR_2 (лин.тренд) order=c(3,0,0),\n    seasonal=c(2,0,0), include.drift = TRUE, include.constant = TRUE
#                  Сезонно сглаженные
# AR_2 (лин.тренд) order=c(4,0,0),\n    include.drift = TRUE, include.constant = TRUE
#                  Месячные
# AR_2 (лин.тренд) order=c(11,0,0),\n    seasonal=c(2,0,0), include.drift = TRUE, include.constant = TRUE
#                      Квартальные Сезонно сглаженные Месячные
# 1 level              61.83956    353.9334           14343.00
# 3 level              62.05967    353.0963           15084.68
# 2 level (state)      62.03617    353.1170           13590.31
# 2 level (type)       61.89342    353.3872           12888.11
# 2 level (clusetered) 62.15618    352.2130           13401.44
# plot without title

# %%
i = 3
paramz[i,]
a[[i]]
grid.arrange(grobs = b[[i]] , ncol = 3)
# Out:
#                     Квартальные
# AR_2 (квадр. тренд) order=c(3,0,0),\n    seasonal=c(2,0,0), include.drift = TRUE, include.constant = TRUE
#                     Сезонно сглаженные
# AR_2 (квадр. тренд) order=c(4,0,0),\n    include.drift = TRUE, include.constant = TRUE
#                     Месячные
# AR_2 (квадр. тренд) order=c(11,0,0),\n    seasonal=c(2,0,0), include.drift = TRUE, include.constant = TRUE
#                      Квартальные Сезонно сглаженные Месячные
# 1 level              88.92257    242.1291            9146.793
# 3 level              89.32797    242.5226           10496.554
# 2 level (state)      89.30700    242.5226           10507.589
# 2 level (type)       89.20774    241.7866            9970.511
# 2 level (clusetered) 89.16447    241.0673           10387.388
# plot without title

# %%
i = 4
paramz[i,]
a[[i]]
grid.arrange(grobs = b[[i]] , ncol = 3)
# Out:
#     Квартальные
# ARI order=c(3,1,0),\n    seasonal=c(2,1,0), include.drift = FALSE, include.constant = FALSE
#     Сезонно сглаженные
# ARI order=c(4,1,0),\n    include.drift = FALSE, include.constant = FALSE
#     Месячные
# ARI order=c(4,0,0),\n    seasonal=c(1,1,0), include.drift = FALSE, include.constant = FALSE
#                      Квартальные Сезонно сглаженные Месячные
# 1 level              78.02445    344.6785           8348.776
# 3 level              77.91876    343.9529           8263.971
# 2 level (state)      77.94299    343.9463           8267.585
# 2 level (type)       77.66904    345.8558           7866.093
# 2 level (clusetered) 77.90293    342.1428           8194.667
# plot without title

# %%
i = 5
paramz[i,]
a[[i]]
grid.arrange(grobs = b[[i]] , ncol = 3)
# Out:
#                  Квартальные
# ARMA (лин.тренд) order=c(3,0,1),\n    seasonal=c(2,0,1), include.drift = TRUE, include.constant = TRUE
#                  Сезонно сглаженные
# ARMA (лин.тренд) order=c(4,0,1),\n     include.drift = TRUE, include.constant = TRUE
#                  Месячные
# ARMA (лин.тренд) order=c(4,0,1),\n    seasonal=c(1,0,1), include.drift = TRUE, include.constant = TRUE)
#                      Квартальные Сезонно сглаженные Месячные
# 1 level              64.78726    377.9760           16758.99
# 3 level              64.27635    376.7024           16137.35
# 2 level (state)      64.91149    376.7413           16139.91
# 2 level (type)       65.23056    375.7386           15851.28
# 2 level (clusetered) 65.07266    375.0489           16049.28
# plot without title

# %%
i = 6
paramz[i,]
a[[i]]
grid.arrange(grobs = b[[i]] , ncol = 3)
# Out:
#       Квартальные
# ARIMA order=c(3,1,1),\n    seasonal=c(2,1,1), include.drift = FALSE, include.constant = FALSE
#       Сезонно сглаженные
# ARIMA order=c(4,1,1),\n  include.drift = FALSE, include.constant = FALSE
#       Месячные
# ARIMA order=c(4,1,1),\n    seasonal=c(1,1,1), include.drift = FALSE, include.constant = FALSE
#                      Квартальные Сезонно сглаженные Месячные
# 1 level              82.46349    320.0250           12274.00
# 3 level              83.34961    319.6023           12126.13
# 2 level (state)      82.52303    319.5933           12131.18
# 2 level (type)       81.81728    321.0356           11896.23
# 2 level (clusetered) 82.25295    317.7805           12057.29
# plot without title

# %%
i = 7
paramz[i,]
a[[i]]
grid.arrange(grobs = b[[i]] , ncol = 3)
# Out:
#                       Квартальные
# ARIMA (автом. подбор)     stationary = FALSE, seasonal = TRUE, lambda=NULL, parallel=TRUE
#                       Сезонно сглаженные
# ARIMA (автом. подбор)     stationary = FALSE, seasonal = FALSE, lambda=NULL, parallel=TRUE
#                       Месячные
# ARIMA (автом. подбор)     stationary = FALSE, seasonal = TRUE, lambda=NULL, parallel=TRUE
#                      Квартальные Сезонно сглаженные Месячные
# 1 level              69.40237    323.9779           13948.14
# 3 level              69.75467    322.2364           13571.27
# 2 level (state)      69.73105    322.2966           13590.31
# 2 level (type)       68.82769    322.3154           12888.11
# 2 level (clusetered) 70.06872    318.5989           13401.44
# plot without title

# %%
i = 8
paramz[i,]
a[[i]]
grid.arrange(grobs = b[[i]] , ncol = 3)
# Out:
#     Квартальные
# ETS model="MMM", damped = FALSE , lambda=NULL
#     Сезонно сглаженные
# ETS model="AAA", damped = FALSE , lambda=NULL
#     Месячные
# ETS model="AAA", damped = TRUE , lambda=NULL
#                      Квартальные Сезонно сглаженные Месячные
# 1 level              64.05969    196.2254           8256.353
# 3 level              64.63630    194.7145           7908.612
# 2 level (state)      64.64086    194.7914           7912.609
# 2 level (type)       63.08983    194.6882           7763.644
# 2 level (clusetered) 63.74245    195.4485           7872.676
# plot without title

# %%
i = 9
paramz[i,]
a[[i]]
grid.arrange(grobs = b[[i]] , ncol = 3)
# Out:
#                     Квартальные Сезонно сглаженные Месячные
# ETS (автом. подбор) lambda=NULL lambda=NULL        lambda=NULL
#                      Квартальные Сезонно сглаженные Месячные
# 1 level              85.57111    309.7325           8015.222
# 3 level              85.22093    308.4589           7695.016
# 2 level (state)      85.22638    308.5041           7698.999
# 2 level (type)       84.82532    305.0175           7789.480
# 2 level (clusetered) 85.17063    303.3762           7682.150
# plot without title

# %%
i = 10
paramz[i,]
a[[i]]
grid.arrange(grobs = b[[i]] , ncol = 3)
# Out:
#       Квартальные
# TBATS use.trend = TRUE, seasonal.periods = var_freq,\n       use.arma.errors=TRUE, use.parallel=TRUE , use.box.cox=FALSE,   use.damped.trend=FALSE
#       Сезонно сглаженные
# TBATS use.trend = TRUE, \n       use.arma.errors=TRUE, use.parallel=TRUE , use.box.cox=FALSE,   use.damped.trend=FALSE
#       Месячные
# TBATS use.trend = TRUE, seasonal.periods = var_freq,\n       use.arma.errors=TRUE, use.parallel=TRUE , use.box.cox=FALSE,   use.damped.trend=TRUE
#                      Квартальные Сезонно сглаженные Месячные
# 1 level              82.75425    153.1218           9449.032
# 3 level              81.81002    152.6632           8683.691
# 2 level (state)      85.09420    152.6817           8691.989
# 2 level (type)       85.21374    154.6652           8004.412
# 2 level (clusetered) 85.12966    152.4131           8571.052
# plot without title

# %%
a
# Out:
# [[1]]
#                      Квартальные Сезонно сглаженные Месячные
# 1 level                 64.30372           299.5702 15884.63
# 3 level                 64.24503           298.8763 15346.86
# 2 level (state)         64.23140           298.8923 15342.24
# 2 level (type)          64.10458           299.4158 15511.31
# 2 level (clusetered)    64.25570           297.5359 15338.88
#
# [[2]]
#                      Квартальные Сезонно сглаженные Месячные
# 1 level                 61.83956           353.9334 14343.00
# 3 level                 62.05967           353.0963 15084.68
# 2 level (state)         62.03617           353.1170 13590.31
# 2 level (type)          61.89342           353.3872 12888.11
# 2 level (clusetered)    62.15618           352.2130 13401.44
#
# [[3]]
#                      Квартальные Сезонно сглаженные  Месячные
# 1 level                 88.92257           242.1291  9146.793
# 3 level                 89.32797           242.5226 10496.554
# 2 level (state)         89.30700           242.5226 10507.589
# 2 level (type)          89.20774           241.7866  9970.511
# 2 level (clusetered)    89.16447           241.0673 10387.388
#
# [[4]]
#                      Квартальные Сезонно сглаженные Месячные
# 1 level                 78.02445           344.6785 8348.776
# 3 level                 77.91876           343.9529 8263.971
# 2 level (state)         77.94299           343.9463 8267.585
# 2 level (type)          77.66904           345.8558 7866.093
# 2 level (clusetered)    77.90293           342.1428 8194.667
#
# [[5]]
#                      Квартальные Сезонно сглаженные Месячные
# 1 level                 64.78726           377.9760 16758.99
# 3 level                 64.27635           376.7024 16137.35
# 2 level (state)         64.91149           376.7413 16139.91
# 2 level (type)          65.23056           375.7386 15851.28
# 2 level (clusetered)    65.07266           375.0489 16049.28
#
# [[6]]
#                      Квартальные Сезонно сглаженные Месячные
# 1 level                 82.46349           320.0250 12274.00
# 3 level                 83.34961           319.6023 12126.13
# 2 level (state)         82.52303           319.5933 12131.18
# 2 level (type)          81.81728           321.0356 11896.23
# 2 level (clusetered)    82.25295           317.7805 12057.29
#
# [[7]]
#                      Квартальные Сезонно сглаженные Месячные
# 1 level                 69.40237           323.9779 13948.14
# 3 level                 69.75467           322.2364 13571.27
# 2 level (state)         69.73105           322.2966 13590.31
# 2 level (type)          68.82769           322.3154 12888.11
# 2 level (clusetered)    70.06872           318.5989 13401.44
#
# [[8]]
#                      Квартальные Сезонно сглаженные Месячные
# 1 level                 64.05969           196.2254 8256.353
# 3 level                 64.63630           194.7145 7908.612
# 2 level (state)         64.64086           194.7914 7912.609
# 2 level (type)          63.08983           194.6882 7763.644
# 2 level (clusetered)    63.74245           195.4485 7872.676
#
# [[9]]
#                      Квартальные Сезонно сглаженные Месячные
# 1 level                 85.57111           309.7325 8015.222
# 3 level                 85.22093           308.4589 7695.016
# 2 level (state)         85.22638           308.5041 7698.999
# 2 level (type)          84.82532           305.0175 7789.480
# 2 level (clusetered)    85.17063           303.3762 7682.150
#
# [[10]]
#                      Квартальные Сезонно сглаженные Месячные
# 1 level                 82.75425           153.1218 9449.032
# 3 level                 81.81002           152.6632 8683.691
# 2 level (state)         85.09420           152.6817 8691.989
# 2 level (type)          85.21374           154.6652 8004.412
# 2 level (clusetered)    85.12966           152.4131 8571.052

# %%
a_perc  <-  a

# %%
for (i in 1:length(a)){
    a_perc[[i]]   <-  data.frame(matrix(unlist(apply(a_perc[[i]],1, function(x) (x/a_perc[[i]][1,]-1)*100 )), ncol =3, byrow =T) )
}

# %%
eu_df <- a_perc[[1]][,1]
us_df <-  a_perc[[1]][,2]
rus_df  <- a_perc[[1]][,3]

# %%
for (i in 2:length(a)){
    eu_df  <-  cbind(eu_df, a_perc[[i]][,1])
    us_df  <-  cbind(us_df, a_perc[[i]][,2])
    rus_df  <-  cbind(rus_df, a_perc[[i]][,3])

}

# %%
# r_names  <- c('AR с линейным трендом (с малым числом лагов)',  'AR с линейным трендом', 'AR с квадратичным трендом', 'Интегрированная AR', 'ARMA с линейным трендом', 'ARIMA', 'ARIMA с автоматическим подбором параметров', 'ETS с фиксированными параметрами', 'ETS с автоматическим подбором параметров', 'TBATS' )
c_names  <- c('1 level','Все ряды', 'Сгрупп. по региону', 'Сгрупп. по типу', ' Сгрупп. по кластерам')

# %%
eu_df  <-  t(eu_df)
colnames(eu_df)  <-  c_names
rownames(eu_df)  <-  r_names
eu_df = as.data.frame(eu_df)
eu_df$'1 level'  <-  NULL

# %%
us_df  <-  t(us_df)
colnames(us_df)  <-  c_names
rownames(us_df)  <-  r_names
us_df = as.data.frame(us_df)
us_df$'1 level'  <-  NULL

# %%
rus_df  <-  t(rus_df)
colnames(rus_df)  <-  c_names
rownames(rus_df)  <-  r_names
rus_df = as.data.frame(rus_df)
rus_df$'1 level'  <-  NULL

# %%
library(forestmangr)

# %%
eu_df  <-  round_df(eu_df, digits = 2)
us_df  <-  round_df(us_df, digits = 2)
rus_df  <-  round_df(rus_df, digits = 2)

# %%
rownames(eu_df) <- rownames(params_score)
rownames(us_df) <- rownames(params_score)
rownames(rus_df) <- rownames(params_score)

# %%
eu_df  <-  eu_df[params_score[['names_eu']],]
us_df  <-  us_df[params_score[['names_us']],]
rus_df  <-  rus_df[params_score[['names_rus']],]

# %%
library(reticulate)

# %%
sns <- import('seaborn')
plt <- import('matplotlib.pyplot')
pd <- import('pandas')

# %%
sns$heatmap(r_to_py(eu_df), fmt="g", cmap =sns$diverging_palette(130, 10, n=15), annot = TRUE, vmin=-10, vmax=10)
#display the plot
plt$show()
# Out:
# AxesSubplot(0.125,0.11;0.62x0.77)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns$heatmap(r_to_py(us_df), fmt="g", cmap =sns$diverging_palette(130, 10, n=15), annot = TRUE, vmin=-10, vmax=10 )
#display the plot
plt$show()
# Out:
# AxesSubplot(0.125,0.11;0.62x0.77)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns$heatmap(r_to_py(rus_df), fmt="g", cmap =sns$diverging_palette(130, 10, n=15), annot = TRUE, vmin=-40, vmax=40)
#display the plot
plt$show()
# Out:
# AxesSubplot(0.125,0.11;0.62x0.77)

# %% [markdown]
# ![image.png](attachment:image.png)
