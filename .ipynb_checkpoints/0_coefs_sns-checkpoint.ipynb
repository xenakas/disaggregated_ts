# %%
import pandas as pd
import seaborn as sns

# %%
df1 = pd.read_csv('coefs_df.csv')

# %%
df1.iloc[:,5:-2]  = df1.iloc[:,5:-2].div(df1.iloc[:,3], axis=0)

# %%
sns.pairplot(df1.iloc[:,3:-1], kind='reg') ;
# Out:
# /home/xenakas/anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/xenakas/anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
df2 = df1[df1.iloc[:,1] == 1]
df3 = df1[df1.iloc[:,1] == 2]
df4 = df1[df1.iloc[:,1] == 3]

# %%
sns.pairplot(df2.iloc[:,3:-1], kind='reg') ;
# Out:
# /home/xenakas/anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/xenakas/anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.pairplot(df3.iloc[:,3:-1], kind='reg') ;
# Out:
# /home/xenakas/anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/xenakas/anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.pairplot(df4.iloc[:,3:-1], kind='reg') ;
# Out:
# /home/xenakas/anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/xenakas/anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
